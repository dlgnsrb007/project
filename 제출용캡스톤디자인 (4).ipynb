# %%
import pandas as pd

# %% [markdown]
# 아마존 판매 데이터를 불러옵니다

# %%
train1 = pd.read_csv('./amazon.csv')

# %%
train1
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %% [markdown]
# 아마존 판매 데이터에서 분석에 필요한 데이터만 가져오기

# %%
list_a = ['product_name','discounted_price', 'actual_price','discount_percentage','rating','rating_count','about_product','review_title','review_content']
train1_list = train1.loc[:, list_a]
train1_list.head()
#제품이름, 제품의 할인된 가격, 제품의 실제 가격, 제품의 할인율, 소비자가 평가한 점수, 평가에 투표한 사람 수, 제품에 대한 설명, 짧은 리뷰, 긴리뷰
# Out:
#                                         product_name discounted_price  \
# 0  Wayona Nylon Braided USB to Lightning Fast Cha...             ₹399
# 1  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...             ₹199
# 2  Sounce Fast Phone Charging Cable & Data Sync U...             ₹199
# 3  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...             ₹329
# 4  Portronics Konnect L 1.2M Fast Charging 3A 8 P...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# 1         ₹349                 43%    4.0       43,994
# 2       ₹1,899                 90%    3.9        7,928
# 3         ₹699                 53%    4.2       94,363
# 4         ₹399                 61%    4.2       16,905
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# ...

# %% [markdown]
# 데이터들의 형태 파악

# %%
train1_list.info()
#모든 데이터들이 객체형입니다
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_name         1465 non-null   object
#  1   discounted_price     1465 non-null   object
#  2   actual_price         1465 non-null   object
#  3   discount_percentage  1465 non-null   object
#  4   rating               1465 non-null   object
#  5   rating_count         1463 non-null   object
#  6   about_product        1465 non-null   object
#  7   review_title         1465 non-null   object
#  8   review_content       1465 non-null   object
# dtypes: object(9)
# memory usage: 103.1+ KB

# %% [markdown]
# 데이터 형태 바꾸기

# %%
train1_list['discounted_price'] = train1_list['discounted_price'].str.replace("₹",'')
train1_list['discounted_price'] = train1_list['discounted_price'].str.replace(",",'')
train1_list['discounted_price'] = train1_list['discounted_price'].astype('float64')
#제품의 할인된 가격 데이터들의 단위와 콤마를 지우고 실수형으로 바꿔줍니다

# %%
train1_list['actual_price'] = train1_list['actual_price'].str.replace("₹",'')
train1_list['actual_price'] = train1_list['actual_price'].str.replace(",",'')
train1_list['actual_price'] = train1_list['actual_price'].astype('float64')
#마찬가지로 제품의 실제 가격 데이터들의 단위와 콤마를 지우고 실수형으로 바꿔줍니다

# %%
train1_list['discount_percentage'] = train1_list['discount_percentage'].str.replace('%','').astype('float64')
#제품의 할인율 데이터들의 퍼센트를 지우고 실수형으로 바꿔줍니다

# %%
train1_list['rating']=train1_list['rating'].astype('float64')
#소비자가 평가한 점수 데이터들의 실수형으로 바꿔주려고 하는데 에러가 나옵니다
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 train1_list['rating']=train1_list['rating'].astype('float64')
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
train1_list['rating'].value_counts()
#에러를 확인하기 위해 값들이 뭐가 있는지 확인하는데 이상치가 있는 것이 확인됩니다
# Out:
# 4.1    244
# 4.3    230
# 4.2    228
# 4.0    129
# 3.9    123
# 4.4    123
# 3.8     86
# 4.5     75
# 4       52
# 3.7     42
# 3.6     35
# 3.5     26
# 4.6     17
# 3.3     16
# 3.4     10
# 4.7      6
# 3.1      4
# 5.0      3
# 3.0      3
# 4.8      3
# 3.2      2
# 2.8      2
# 2.3      1
# |        1
# 2        1
# 3        1
# 2.6      1
# 2.9      1
# Name: rating, dtype: int64

# %%
train1_list.drop(train1_list.loc[train1_list['rating']=='|'].index, inplace=True)
#소비자가 평가한 점수 데이터에 이상치가 있는 행을 지워 해결합니다

# %%
train1_list['rating'].value_counts()
#지워진 것을 확인합니다
# Out:
# 4.1    244
# 4.3    230
# 4.2    228
# 4.0    129
# 3.9    123
# 4.4    123
# 3.8     86
# 4.5     75
# 4       52
# 3.7     42
# 3.6     35
# 3.5     26
# 4.6     17
# 3.3     16
# 3.4     10
# 4.7      6
# 3.1      4
# 5.0      3
# 3.0      3
# 4.8      3
# 3.2      2
# 2.8      2
# 2.3      1
# 2        1
# 3        1
# 2.6      1
# 2.9      1
# Name: rating, dtype: int64

# %%
train1_list['rating']=train1_list['rating'].astype('float64')
#다시 소비자가 평가한 점수 데이터들을 실수형으로 바꿔줍니다

# %%
train1_list['rating_count'] = train1_list['rating_count'].str.replace(',', '').astype('float64')
#평가에 투표한 사람 수 데이터들의 콤마를 지우고 실수형으로 바꿔줍니다

# %%
train1_list.info()
#데이터의 형태가 잘 바뀌었는지 확인합니다
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1464 entries, 0 to 1464
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_name         1464 non-null   object
#  1   discounted_price     1464 non-null   float64
#  2   actual_price         1464 non-null   float64
#  3   discount_percentage  1464 non-null   float64
#  4   rating               1464 non-null   float64
#  5   rating_count         1462 non-null   float64
#  6   about_product        1464 non-null   object
#  7   review_title         1464 non-null   object
#  8   review_content       1464 non-null   object
# dtypes: float64(5), object(4)
# memory usage: 114.4+ KB

# %%
train1_list
# Out:
#                                            product_name  discounted_price  \
# 0     Wayona Nylon Braided USB to Lightning Fast Cha...             399.0
# 1     Ambrane Unbreakable 60W / 3A Fast Charging 1.5...             199.0
# 2     Sounce Fast Phone Charging Cable & Data Sync U...             199.0
# 3     boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...             329.0
# 4     Portronics Konnect L 1.2M Fast Charging 3A 8 P...             154.0
# ...                                                 ...               ...
# 1460  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...             379.0
# 1461  Prestige Delight PRWO Electric Rice Cooker (1 ...            2280.0
# 1462  Bajaj Majesty RX10 2000 Watts Heat Convector R...            2219.0
# 1463  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...            1399.0
# 1464  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...            2863.0
#
#       actual_price  discount_percentage  rating  rating_count  \
# ...

# %%
train1_list.loc[train1_list['rating'] >= 4.3, 'new_rating'] = 'A'
train1_list.loc[(train1_list['rating'] >= 4.1) & (train1_list['rating'] < 4.3), 'new_rating'] = 'B'
train1_list.loc[train1_list['rating'] <= 4.0, 'new_rating'] = 'C'

# %%
train1_list
# Out:
#                                            product_name  discounted_price  \
# 0     Wayona Nylon Braided USB to Lightning Fast Cha...             399.0
# 1     Ambrane Unbreakable 60W / 3A Fast Charging 1.5...             199.0
# 2     Sounce Fast Phone Charging Cable & Data Sync U...             199.0
# 3     boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...             329.0
# 4     Portronics Konnect L 1.2M Fast Charging 3A 8 P...             154.0
# ...                                                 ...               ...
# 1460  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...             379.0
# 1461  Prestige Delight PRWO Electric Rice Cooker (1 ...            2280.0
# 1462  Bajaj Majesty RX10 2000 Watts Heat Convector R...            2219.0
# 1463  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...            1399.0
# 1464  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...            2863.0
#
#       actual_price  discount_percentage  rating  rating_count  \
# ...

# %%
train1_list['new_rating'].value_counts()
# Out:
# C    535
# B    472
# A    457
# Name: new_rating, dtype: int64

# %%
train1_list['rating'].value_counts()
# Out:
# 4.1    244
# 4.3    230
# 4.2    228
# 4.0    181
# 3.9    123
# 4.4    123
# 3.8     86
# 4.5     75
# 3.7     42
# 3.6     35
# 3.5     26
# 4.6     17
# 3.3     16
# 3.4     10
# 4.7      6
# 3.0      4
# 3.1      4
# 5.0      3
# 4.8      3
# 3.2      2
# 2.8      2
# 2.3      1
# 2.0      1
# 2.6      1
# 2.9      1
# Name: rating, dtype: int64

# %%
train1_list.isna().any()
#컬럼별로 na값이 있는 지 확인하는데 분석에 필요한 수치형 데이터들은 na값이 없습니다
# Out:
# product_name           False
# discounted_price       False
# actual_price           False
# discount_percentage    False
# rating                 False
# rating_count            True
# about_product          False
# review_title           False
# review_content         False
# new_rating             False
# dtype: bool

# %%
train1_list['rating_count'].isnull().sum()
# Out:
# 2

# %%
train1_list=train1_list.dropna()

# %%
train1_list.isna().any()
# Out:
# product_name           False
# discounted_price       False
# actual_price           False
# discount_percentage    False
# rating                 False
# rating_count           False
# about_product          False
# review_title           False
# review_content         False
# new_rating             False
# dtype: bool

# %%
train1_list['discount_percentage'] = train1_list['discount_percentage']/100
#할인율은 퍼센트이기때문에 100 나눠준다
# Out:
# C:\Users\hk679\AppData\Local\Temp\ipykernel_19548\2407741778.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train1_list['discount_percentage'] = train1_list['discount_percentage']/100

# %%
train1_list.head()
# Out:
#                                         product_name  discounted_price  \
# 0  Wayona Nylon Braided USB to Lightning Fast Cha...             399.0
# 1  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...             199.0
# 2  Sounce Fast Phone Charging Cable & Data Sync U...             199.0
# 3  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...             329.0
# 4  Portronics Konnect L 1.2M Fast Charging 3A 8 P...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                 0.64     4.2       24269.0
# 1         349.0                 0.43     4.0       43994.0
# 2        1899.0                 0.90     3.9        7928.0
# 3         699.0                 0.53     4.2       94363.0
# 4         399.0                 0.61     4.2       16905.0
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# ...

# %% [markdown]
# 텍스트마이닝 뉴평점, 짧은리뷰

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import confusion_matrix
import numpy as np

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(train1_list['review_title'])

# %%
y = train1_list['new_rating']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
clf = MultinomialNB()
clf.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = clf.predict(X_test)
cm = confusion_matrix(y_test, y_pred, labels=['A', 'B', 'C'])
fig, ax = plt.subplots(figsize=(5,5))
im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=['A', 'B', 'C'], yticklabels=['A', 'B', 'C'], xlabel='Predicted', ylabel='True')
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, cm[i, j], ha='center', va='center')

# %% [markdown]
# 뉴평점, 짧은리뷰+긴리뷰

# %%
#전처리:특수문자제거, 소문자 변환
train1_list['review_title']=train1_list['review_title'].str.replace('[^\w\s]','')
train1_list['review_content']=train1_list['review_content'].str.replace('[^\w\s]','')
train1_list['review_title']=train1_list['review_title'].str.lower()
train1_list['review_content']=train1_list['review_content'].str.lower()
# Out:
# C:\Users\hk679\AppData\Local\Temp\ipykernel_18656\2293341349.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   train1_list['review_title']=train1_list['review_title'].str.replace('[^\w\s]','')
# C:\Users\hk679\AppData\Local\Temp\ipykernel_18656\2293341349.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train1_list['review_title']=train1_list['review_title'].str.replace('[^\w\s]','')
# C:\Users\hk679\AppData\Local\Temp\ipykernel_18656\2293341349.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   train1_list['review_content']=train1_list['review_content'].str.replace('[^\w\s]','')
# ...

# %%
train1_list['new_review']=train1_list['review_title']+' '+train1_list['review_content']
# Out:
# C:\Users\hk679\AppData\Local\Temp\ipykernel_18656\2601383283.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train1_list['new_review']=train1_list['review_title']+' '+train1_list['review_content']

# %%
train1_list['review_title'][0]
# Out:
# 'satisfiedcharging is really fastvalue for moneyproduct reviewgood qualitygood productgood productas of now seems good'

# %%
train1_list['review_content'][0]
# Out:
# 'looks durable charging is fine toono complainscharging is really fast good producttill now satisfied with the qualitythis is a good product  the charging speed is slower than the original iphone cablegood quality would recommendhttpsmmediaamazoncomimageswwebp_402378t1imagesi81f1zghl_sy88jpgproduct had worked well till date and was having no issuecable is also sturdy enoughhave asked for replacement and company is doing the samevalue for money'

# %%
train1_list['new_review'][0]
# Out:
# 'satisfiedcharging is really fastvalue for moneyproduct reviewgood qualitygood productgood productas of now seems good looks durable charging is fine toono complainscharging is really fast good producttill now satisfied with the qualitythis is a good product  the charging speed is slower than the original iphone cablegood quality would recommendhttpsmmediaamazoncomimageswwebp_402378t1imagesi81f1zghl_sy88jpgproduct had worked well till date and was having no issuecable is also sturdy enoughhave asked for replacement and company is doing the samevalue for money'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(train1_list['new_review'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, train1_list['new_rating'], test_size=0.3, random_state=42)

# %%
model = MultinomialNB()
model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
accuracy = model.score(X_test, y_test)
print('Accuracy:', accuracy)
# Out:
# Accuracy: 0.48519362186788156

# %% [markdown]
# 데이터 특성 시각화

# %%
import matplotlib.pyplot as plt
from mlxtend.plotting import scatterplotmatrix

# %%
train1_list_a = ['discounted_price', 'actual_price', 'discount_percentage', 'rating', 'rating_count']

scatterplotmatrix(train1_list[train1_list_a].values, figsize=(10, 8), 
                  names=train1_list_a, alpha=0.5)
plt.tight_layout()

plt.show()

# %%
import numpy as np
from mlxtend.plotting import heatmap


cm = np.corrcoef(train1_list[train1_list_a].values.T)
hm = heatmap(cm, row_names=train1_list_a, column_names=train1_list_a)

# plt.savefig('images/10_04.png', dpi=300)
plt.show()

# %% [markdown]
# 경사 하강법으로 회귀 모델의 파라미터 구하기

# %%
class LinearRegressionGD(object):

    def __init__(self, eta=0.001, n_iter=20):
        self.eta = eta
        self.n_iter = n_iter

    def fit(self, X, y):
        self.w_ = np.zeros(1 + X.shape[1])
        self.cost_ = []

        for i in range(self.n_iter):
            output = self.net_input(X)
            errors = (y - output)
            self.w_[1:] += self.eta * X.T.dot(errors)
            self.w_[0] += self.eta * errors.sum()
            cost = (errors**2).sum() / 2.0
            self.cost_.append(cost)
        return self

    def net_input(self, X):
        return np.dot(X, self.w_[1:]) + self.w_[0]

    def predict(self, X):
        return self.net_input(X)

# %%
x = train1_list[['discount_percentage']].values
y = train1_list['rating'].values

# %%
from sklearn.preprocessing import StandardScaler


sc_x = StandardScaler()
sc_y = StandardScaler()
x_std = sc_x.fit_transform(x)
y_std = sc_y.fit_transform(y[:, np.newaxis]).flatten()
#정규화 작업을 해줍니다, 이유는 할인율은 0부터1까지, 평점은 0부터 5까지이기때문

# %%
lr = LinearRegressionGD()
lr.fit(x_std, y_std)

# %%
plt.plot(range(1, lr.n_iter+1), lr.cost_)
plt.ylabel('SSE')
plt.xlabel('Epoch')
plt.tight_layout()
# plt.savefig('images/10_05.png', dpi=300)
plt.show()
#반복학습을 할수록 오차값이 떨어진다

# %%
def lin_regplot(X, y, model):
    plt.scatter(X, y, c='steelblue', edgecolor='white', s=70)
    plt.plot(X, model.predict(X), color='black', lw=2)    
    return

# %%
lin_regplot(x_std, y_std, lr)
plt.xlabel('[discount_percentage]')
plt.ylabel('[rating]')


plt.show()
#제품의 할인율에 대한 소비자 평점의 기울기

# %%
print('기울기: %.3f' % lr.w_[1])
print('절편: %.3f' % lr.w_[0])
# Out:
# 기울기: -0.155
# 절편: -0.000

# %%
x1 = train1_list[['actual_price']].values
y1 = train1_list['rating'].values

# %%
sc_x1 = StandardScaler()
sc_y1 = StandardScaler()
x1_std = sc_x1.fit_transform(x1)
y1_std = sc_y1.fit_transform(y1[:, np.newaxis]).flatten()

# %%
lr1 = LinearRegressionGD()
lr1.fit(x1_std, y1_std)

# %%
plt.plot(range(1, lr1.n_iter+1), lr1.cost_)
plt.ylabel('SSE')
plt.xlabel('Epoch')
plt.tight_layout()
# plt.savefig('images/10_05.png', dpi=300)
plt.show()

# %%
lin_regplot(x1_std, y1_std, lr1)
plt.xlabel('[actual_price]')
plt.ylabel('[rating]')


plt.show()
#제품의 실제 가격에 대한 소비자 평점의 기울기

# %%
print('기울기: %.3f' % lr1.w_[1])
print('절편: %.3f' % lr1.w_[0])
# Out:
# 기울기: 0.122
# 절편: -0.000

# %%
x2 = train1_list[['discounted_price']].values
y2 = train1_list['rating'].values

# %%
sc_x2= StandardScaler()
sc_y2 = StandardScaler()
x2_std = sc_x2.fit_transform(x2)
y2_std = sc_y2.fit_transform(y2[:, np.newaxis]).flatten()

# %%
lr2 = LinearRegressionGD()
lr2.fit(x2_std, y2_std)

# %%
plt.plot(range(1, lr2.n_iter+1), lr2.cost_)
plt.ylabel('SSE')
plt.xlabel('Epoch')
plt.tight_layout()
# plt.savefig('images/10_05.png', dpi=300)
plt.show()

# %%
lin_regplot(x2_std, y2_std, lr2)
plt.xlabel('[discounted_price]')
plt.ylabel('[rating]')


plt.show()
#제품의 할인된 가격에 대한 소비자 평점의 기울기

# %%
print('기울기: %.3f' % lr2.w_[1])
print('절편: %.3f' % lr2.w_[0])
# Out:
# 기울기: 0.120
# 절편: -0.000

# %% [markdown]
# 사이킷런으로 그나마 기울기가 있는 제품의 할인율에 대한 소비자 평점 회귀 모델의 가중치 추정

# %%
from sklearn.linear_model import LinearRegression

# %%
slr = LinearRegression()
slr.fit(x, y)
y_pred = slr.predict(x)
print('기울기: %.3f' % slr.coef_[0])
print('절편: %.3f' % slr.intercept_)
# Out:
# 기울기: -0.210
# 절편: 4.197

# %%
lin_regplot(x, y, slr)
plt.xlabel('[discount_percentage]')
plt.ylabel('[rating]')

# plt.savefig('images/10_07.png', dpi=300)
plt.show()

# %% [markdown]
# RANSAC을 사용하여 안정된 제품의 할인율에 대한 소비자 평점 회귀 모델 훈련

# %%
from sklearn.linear_model import RANSACRegressor

ransac = RANSACRegressor(LinearRegression(), 
                         max_trials=100, 
                         min_samples=50, 
                         loss='absolute_error', 
                          
                         random_state=0)


ransac.fit(x, y)

inlier_mask = ransac.inlier_mask_
outlier_mask = np.logical_not(inlier_mask)

line_X = np.arange(0, 3, 1)
line_y_ransac = ransac.predict(line_X[:, np.newaxis])
plt.scatter(x[inlier_mask], y[inlier_mask],
            c='steelblue', edgecolor='white', 
            marker='o', label='Inliers')
plt.scatter(x[outlier_mask], y[outlier_mask],
            c='limegreen', edgecolor='white', 
            marker='s', label='Outliers')
plt.plot(line_X, line_y_ransac, color='black', lw=2)   
plt.xlabel('[discount_percentage]')
plt.ylabel('[rating]')
plt.legend(loc='upper left')

# plt.savefig('images/10_08.png', dpi=300)
plt.show()

# %%
print('기울기: %.3f' % ransac.estimator_.coef_[0])
print('절편: %.3f' % ransac.estimator_.intercept_)
# Out:
# 기울기: -0.087
# 절편: 4.190

# %% [markdown]
# 선형 회귀모델 성능 평가

# %%
train1_list
# Out:
#                                            product_name  discounted_price  \
# 0     Wayona Nylon Braided USB to Lightning Fast Cha...             399.0
# 1     Ambrane Unbreakable 60W / 3A Fast Charging 1.5...             199.0
# 2     Sounce Fast Phone Charging Cable & Data Sync U...             199.0
# 3     boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...             329.0
# 4     Portronics Konnect L 1.2M Fast Charging 3A 8 P...             154.0
# ...                                                 ...               ...
# 1460  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...             379.0
# 1461  Prestige Delight PRWO Electric Rice Cooker (1 ...            2280.0
# 1462  Bajaj Majesty RX10 2000 Watts Heat Convector R...            2219.0
# 1463  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...            1399.0
# 1464  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...            2863.0
#
#       actual_price  discount_percentage  rating  rating_count  \
# ...

# %%
train1_list_a = ['discounted_price', 'actual_price', 'discount_percentage', 'rating', 'rating_count']
train1_list1 = train1_list.loc[:, train1_list_a]

# %%
from sklearn.model_selection import train_test_split

X = train1_list1.iloc[:, :-1].values
y = train1_list1['rating'].values

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=0)
#y값에 평점을 두고 트레인, 테스트 비율 7대3으로 나눠줬습니다

# %%
slr = LinearRegression()

slr.fit(X_train, y_train)
y_train_pred = slr.predict(X_train)
y_test_pred = slr.predict(X_test)

# %%
plt.scatter(y_train_pred,  y_train_pred - y_train,
            c='steelblue', marker='o', edgecolor='white',
            label='Training data')
plt.scatter(y_test_pred,  y_test_pred - y_test,
            c='limegreen', marker='s', edgecolor='white',
            label='Test data')
plt.xlabel('Predicted values')
plt.ylabel('Residuals')
plt.legend(loc='upper left')
plt.hlines(y=0, xmin=-10, xmax=50, color='black', lw=2)
plt.xlim([0, 6])
plt.tight_layout()


plt.show()
#결과가 안좋다

# %%
from sklearn.tree import DecisionTreeRegressor

X = train1_list[['discount_percentage']].values
y = train1_list['rating'].values

tree = DecisionTreeRegressor(max_depth=3)
tree.fit(X, y)

sort_idx = X.flatten().argsort()

lin_regplot(X[sort_idx], y[sort_idx], tree)
plt.xlabel('discount_percentage')
plt.ylabel('rating')

plt.show()
#결정트리 회귀를 해도 결과가 좋지 않다

# %% [markdown]
# 새로운 데이터 가져오기(쇼핑 고객 데이터)

# %%
train2 = pd.read_csv('./Customers.csv')

# %%
train2
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
list2_a = ['Age','Annual Income ($)', 'Spending Score (1-100)','Work Experience','Family Size']
train2_list2 = train2.loc[:, list2_a]
train2_list2.head()
#나이, 연간 소득, 지출 점수, 업무 경험-년, 가족 규모
# Out:
#    Age  Annual Income ($)  Spending Score (1-100)  Work Experience  \
# 0   19              15000                      39                1
# 1   21              35000                      81                3
# 2   20              86000                       6                1
# 3   23              59000                      77                0
# 4   31              38000                      40                2
#
#    Family Size
# 0            4
# 1            3
# 2            1
# 3            2
# 4            6

# %%
train2_list2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     2000 non-null   int64
#  1   Annual Income ($)       2000 non-null   int64
#  2   Spending Score (1-100)  2000 non-null   int64
#  3   Work Experience         2000 non-null   int64
#  4   Family Size             2000 non-null   int64
# dtypes: int64(5)
# memory usage: 78.2 KB

# %% [markdown]
# 데이터 특성 시각화

# %%
scatterplotmatrix(train2[list2_a].values, figsize=(10, 8), 
                  names=list2_a, alpha=0.5)
plt.tight_layout()

# %%
cm2 = np.corrcoef(train2[list2_a].values.T)
hm2 = heatmap(cm2, row_names=list2_a, column_names=list2_a)


plt.show()
#상관관계 값이 작다
